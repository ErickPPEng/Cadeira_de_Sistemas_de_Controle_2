# %%
import numpy as np
import matplotlib.pyplot as plt
# from numpy import zeros, arange

# %%
A = np.zeros(5)
B = np.arange(5)

# %%
print(A)
print(B)
# Out:
# [0. 0. 0. 0. 0.]
# [0 1 2 3 4]

# %%
for i in range(10):
  if i in B:
    print(i)
  else:
    print('Não está na matriz')
# Out:
# 0
# 1
# 2
# 3
# 4
# Não está na matriz
# Não está na matriz
# Não está na matriz
# Não está na matriz
# Não está na matriz
