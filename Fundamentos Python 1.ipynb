# %%
a = 12
b = 5
x = 3.3

# %%
print(a + b)
print(3 * 6)
print(5 ** 2)
print(17/3)
# Out:
# 17
# 18
# 25
# 5.666666666666667

# %%
print('Sistemas de controle!!')
print("Python")
# Out:
# Sistemas de controle!!
# Python

# %%
print('A' + 2*'ra')
# Out:
# Arara

# %%
print(x + b)
calculo = 5*x + a
print(calculo)
# Out:
# 8.3
# 28.5

# %%
# Isso é um comentário!
""" Esse também é um comentário!! """
''' E esse mais um comentário. '''
# Out:
# ' E esse mais um comentário. '

# %%
# print(1 + 2)
4 * 5
print('printa sempre o ultmo!')
# Out:
# printa sempre o ultmo!

# %%
3 > 4
a >= 3
a != b
x == 3.3
3 == '3'
# Out:
# False

# %%
a = a - 12
print(a)
# Out:
# 0

# %%
b += 2
print(b)
# Out:
# 7

# %%
lista = [2, 'python', 7.2, 12, 'Controle']

# %%
lista[0] = 0

# %%
lista
# Out:
# [0, 'python', 7.2, 12, 'Controle']

# %%
lista[-2]
# Out:
# 12

# %%
2 in lista
'python' in lista
'controle' in lista
# Out:
# False
